# %%
# Dependencies & Setup
import pandas as pd

# Files to Load
country_codes_csv = "initial-data/country-codes.csv"
vaccinations_csv = "initial-data/vaccination-data.csv"
daily_cases_csv = "initial-data/WHO-COVID-19-global-data.csv"

# Read the files & store into pandas dataframes
country_data = pd.read_csv(country_codes_csv)
vaccination_data = pd.read_csv(vaccinations_csv)
case_data = pd.read_csv(daily_cases_csv)

# %%
# Create a clean vaccine dataframe
vaccine_df = pd.merge(country_data, vaccination_data, left_on="Alpha-3 code", right_on="ISO3")
vaccine_df.drop(['COUNTRY', 'ISO3'], axis=1, inplace=True)
vaccine_df.rename(columns={'Latitude (average)': 'Latitude', 'Longitude (average': 'Longitude'}, inplace=True)
vaccine_df = vaccine_df.drop_duplicates(subset=["Alpha-3 code"])
vaccine_df

#country_data
#vaccination_data
# Out:
#                      Country Alpha-2 code Alpha-3 code  Numeric code  \
# 0                Afghanistan           AF          AFG             4
# 1                    Albania           AL          ALB             8
# 2                    Algeria           DZ          DZA            12
# 3             American Samoa           AS          ASM            16
# 4                    Andorra           AD          AND            20
# ..                       ...          ...          ...           ...
# 227  Virgin Islands, British           VG          VGB            92
# 228        Wallis and Futuna           WF          WLF           876
# 229                    Yemen           YE          YEM           887
# 230                   Zambia           ZM          ZMB           894
# 231                 Zimbabwe           ZW          ZWE           716
#
#      Latitude  Longitude (average) WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0     33.0000                 65.0       EMRO   REPORTING   2022-03-06
# 1     41.0000                 20.0       EURO   REPORTING   2022-02-20
# 2     28.0000                  3.0       AFRO   REPORTING   2022-02-20
# 3    -14.3333               -170.0       WPRO   REPORTING   2022-02-16
# 4     42.5000                  1.6       EURO   REPORTING   2022-02-13
# ..        ...                  ...        ...         ...          ...
# 227   18.5000                -64.5       AMRO   REPORTING   2022-02-25
# 228  -13.3000               -176.2       WPRO   REPORTING   2022-02-18
# 229   15.0000                 48.0       EMRO   REPORTING   2022-03-06
# 230  -15.0000                 30.0       AFRO   REPORTING   2022-03-03
# 231  -20.0000                 30.0       AFRO   REPORTING   2022-03-04
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0               5597130                      4952744.0
# 1               2707658                      1284034.0
# 2              13631683                      7456361.0
# 3                 85050                        42212.0
# 4                142420                        57797.0
# ..                  ...                            ...
# 227               36610                        18923.0
# 228               15633                         6450.0
# 229              784792                       624837.0
# 230             2858338                      2510296.0
# 231             7904719                      4368633.0
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                       14.378                                12.723
# 1                       94.100                                45.118
# 2                       31.086                                17.004
# 3                      154.084                                76.475
# 4                      184.300                                75.872
# ..                         ...                                   ...
# 227                    121.077                                62.582
# 228                    139.009                                57.354
# 229                      2.631                                 2.095
# 230                     15.548                                13.655
# 231                     53.184                                29.393
#
#      PERSONS_FULLY_VACCINATED  PERSONS_FULLY_VACCINATED_PER100  \
# 0                   4281934.0                           11.000
# 1                   1192155.0                           41.889
# 2                   6076272.0                           13.857
# 3                     37805.0                           68.491
# 4                     53250.0                           69.903
# ..                        ...                              ...
# 227                   17325.0                           57.297
# 228                    6399.0                           56.900
# 229                  384655.0                            1.290
# 230                 1883799.0                           10.247
# 231                 3403501.0                           22.899
#
#                                          VACCINES_USED FIRST_VACCINE_DATE  \
# 0    Beijing CNBG - BBIBP-CorV,Janssen - Ad26.COV 2...         2021-02-22
# 1    AstraZeneca - Vaxzevria,Gamaleya - Gam-Covid-V...         2021-01-13
# 2    Beijing CNBG - BBIBP-CorV,Gamaleya - Gam-Covid...         2021-01-30
# 3    Janssen - Ad26.COV 2-S,Moderna - Spikevax,Pfiz...         2020-12-21
# 4    AstraZeneca - Vaxzevria,Moderna - Spikevax,Pfi...         2021-01-20
# ..                                                 ...                ...
# 227     AstraZeneca - Vaxzevria,Janssen - Ad26.COV 2-S         2021-02-11
# 228                                 Moderna - Spikevax         2021-03-19
# 229  Janssen - Ad26.COV 2-S,SII - Covishield,Sinova...         2021-04-20
# 230  Beijing CNBG - BBIBP-CorV,Janssen - Ad26.COV 2...         2021-04-14
# 231  Beijing CNBG - BBIBP-CorV,Bharat - Covaxin,Gam...         2021-02-18
#
#      NUMBER_VACCINES_TYPES_USED
# 0                           4.0
# 1                           5.0
# 2                           4.0
# 3                           3.0
# 4                           3.0
# ..                          ...
# 227                         2.0
# 228                         1.0
# 229                         3.0
# 230                         3.0
# 231                         4.0
#
# [221 rows x 18 columns]

# %%
# Create a clean cases dataframe
cases_df = pd.merge(country_data, case_data, left_on="Alpha-2 code", right_on="Country_code")
cases_df.drop(['Country_code', 'Country_y'], axis=1, inplace=True)
cases_df.rename(columns={'Country_x': 'Country','Latitude (average)': 'Latitude', 'Longitude (average': 'Longitude'}, inplace=True)
cases_df = cases_df.drop_duplicates(subset=["Alpha-3 code", "Date_reported"])
cases_df
# Out:
#             Country Alpha-2 code Alpha-3 code  Numeric code  Latitude  \
# 0       Afghanistan           AF          AFG             4      33.0
# 1       Afghanistan           AF          AFG             4      33.0
# 2       Afghanistan           AF          AFG             4      33.0
# 3       Afghanistan           AF          AFG             4      33.0
# 4       Afghanistan           AF          AFG             4      33.0
# ...             ...          ...          ...           ...       ...
# 188566     Zimbabwe           ZW          ZWE           716     -20.0
# 188567     Zimbabwe           ZW          ZWE           716     -20.0
# 188568     Zimbabwe           ZW          ZWE           716     -20.0
# 188569     Zimbabwe           ZW          ZWE           716     -20.0
# 188570     Zimbabwe           ZW          ZWE           716     -20.0
#
#         Longitude (average) Date_reported WHO_region  New_cases  \
# 0                      65.0    2020-01-03       EMRO          0
# 1                      65.0    2020-01-04       EMRO          0
# 2                      65.0    2020-01-05       EMRO          0
# 3                      65.0    2020-01-06       EMRO          0
# 4                      65.0    2020-01-07       EMRO          0
# ...                     ...           ...        ...        ...
# 188566                 30.0    2022-02-25       AFRO        378
# 188567                 30.0    2022-02-26       AFRO        500
# 188568                 30.0    2022-02-27       AFRO        336
# 188569                 30.0    2022-02-28       AFRO          0
# 188570                 30.0    2022-03-01       AFRO        577
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# 1                      0           0                  0
# 2                      0           0                  0
# 3                      0           0                  0
# 4                      0           0                  0
# ...                  ...         ...                ...
# 188566            234967           2               5390
# 188567            235467           2               5392
# 188568            235803           1               5393
# 188569            235803           0               5393
# 188570            236380           2               5395
#
# [179892 rows x 12 columns]

# %%
# Export the cleaned files to csv
vaccine_df.to_csv("cleaned-data/vaccine-data.csv", index = False)
cases_df.to_csv("cleaned-data/cases-data.csv", index = False)
